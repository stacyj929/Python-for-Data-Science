# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
reviews = pd.read_csv('winemag-data_first150k.csv', index_col=0)

# %%
#Exploratory Data Analysis (EDA)
#reviews.shape       #rows by columns
# reviews.columns       #get all column names
# reviews.dtypes     # datatypes
# reviews.info()     # more detailed info
# reviews.describe()
# reviews.isnull().sum()   Tells you the number of null values in each column
# reviews.notnull().sum()   Tells you the number of non missing values in each column

# %% [markdown]
# Subsetting dataframe

# %%
# reviews.loc[:,'price']    #How to view all price columns
# reviews['price']
reviews['price'].plot(kind='hist')
plt.show()

# %%
# %matplotlib inline

# %%
reviews['province'].value_counts().head(10).plot(kind='bar')

# reviews['province'].value_counts()

# %%
# plot precentage of the top 10 provinces 
(reviews['province'].value_counts().head(10)/len(reviews)).plot(kind='bar')

# %%
reviews['points'].value_counts().plot(kind='bar')

# %%
#shows the values organized by index instead of frequency
reviews['points'].value_counts().sort_index().plot(kind='bar')

# %%
reviews['points'].value_counts().sort_index().plot(kind='area')

# %%
#Step 1: find subset with price < $200
# reviews[reviews['price'] < 200]

#Step 2: What does this subset look like 
# reviews[reviews['price'] < 200].shape

#step 3: PLot wines under $200 
reviews[reviews['price'] < 200]['price'].plot(kind='hist')
